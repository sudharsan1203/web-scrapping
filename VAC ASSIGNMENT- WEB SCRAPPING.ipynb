# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?sid=j9e%2Fabm%2Fhzg&otracker=CLP_Filters&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG"

# %%
allow= requests.get(url)

# %%
print(allow)
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.select("._4rR01T")

# %%
product_name
# Out:
# [<div class="_4rR01T">SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer  with Digi Touch Cool</div>,
#  <div class="_4rR01T">SAMSUNG 253 L Frost Free Double Door 2 Star Convertible Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer</div>,
#  <div class="_4rR01T">SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer</div>,
#  <div class="_4rR01T">SAMSUNG 198 L Direct Cool Single Door 5 Star Refrigerator with Base Drawer</div>,
#  <div class="_4rR01T">SAMSUNG 670 L Frost Free Double Door 2 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 230 L Direct Cool Single Door 3 Star Refrigerator with Base Drawer</div>,
# ...

# %%
product_rate=soup.select("._1_WHN1")

# %%
product_rate
# Out:
# [<div class="_30jeq3 _1_WHN1">₹13,190</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,700</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,750</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,750</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,000</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,800</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,390</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,090</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,550</div>,
#  <div class="_30jeq3 _1_WHN1">₹22,600</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,900</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,590</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,050</div>,
#  <div class="_30jeq3 _1_WHN1">₹61,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,090</div>,
# ...

# %%
product_list=[]
product_junk=[]

# %%
for item in product_name:
    product_list.append(item.text)
    junk = "https://www.flipkart.com"
    product_junk.append(junk)

# %%
product_list
# Out:
# ['SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator',
#  'SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator',
#  'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer  with Digi Touch Cool',
#  'SAMSUNG 253 L Frost Free Double Door 2 Star Convertible Refrigerator',
#  'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer',
#  'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer',
#  'SAMSUNG 198 L Direct Cool Single Door 5 Star Refrigerator with Base Drawer',
#  'SAMSUNG 670 L Frost Free Double Door 2 Star Refrigerator',
#  'SAMSUNG 230 L Direct Cool Single Door 3 Star Refrigerator with Base Drawer',
#  'SAMSUNG 230 L Direct Cool Single Door 3 Star Refrigerator',
#  'SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator',
#  'SAMSUNG 253 L Frost Free Double Door 2 Star Refrigerator with Base Drawer',
#  'SAMSUNG 345 L Frost Free Double Door 3 Star Convertible Refrigerator',
# ...

# %%
rate_list=[]

# %%
for item in product_rate:
    rate_list.append(item.text)

# %%
rate_list
# Out:
# ['₹13,190',
#  '₹24,490',
#  '₹16,700',
#  '₹25,990',
#  '₹16,750',
#  '₹16,750',
#  '₹18,000',
#  '₹75,800',
#  '₹18,390',
#  '₹17,090',
#  '₹14,490',
#  '₹28,490',
#  '₹36,550',
#  '₹22,600',
#  '₹17,900',
#  '₹36,490',
#  '₹26,290',
#  '₹14,590',
#  '₹37,050',
#  '₹61,990',
#  '₹15,090',
#  '₹20,490',
#  '₹34,790',
#  '₹27,499']

# %%
import pandas as pd

# %%
product_name=pd.DataFrame(product_list,columns=["Refrigirator_name"])

# %%
product_name["Rate"]=rate_list

# %%
product_name
# Out:
#                                     Refrigirator_name     Rate
# 0   SAMSUNG 192 L Direct Cool Single Door 2 Star R...  ₹13,190
# 1   SAMSUNG 253 L Frost Free Double Door 3 Star Re...  ₹24,490
# 2   SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,700
# 3   SAMSUNG 253 L Frost Free Double Door 2 Star Co...  ₹25,990
# 4   SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,750
# 5   SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,750
# 6   SAMSUNG 198 L Direct Cool Single Door 5 Star R...  ₹18,000
# 7   SAMSUNG 670 L Frost Free Double Door 2 Star Re...  ₹75,800
# 8   SAMSUNG 230 L Direct Cool Single Door 3 Star R...  ₹18,390
# 9   SAMSUNG 230 L Direct Cool Single Door 3 Star R...  ₹17,090
# 10  SAMSUNG 192 L Direct Cool Single Door 2 Star R...  ₹14,490
# 11  SAMSUNG 253 L Frost Free Double Door 2 Star Re...  ₹28,490
# 12  SAMSUNG 345 L Frost Free Double Door 3 Star Co...  ₹36,550
# 13  SAMSUNG 253 l Frost Free Double Door 2 Star Re...  ₹22,600
# ...

# %%
product_name.to_csv("assignment.csv")
